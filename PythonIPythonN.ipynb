# %% [markdown]
# # Python &  IPython Notebook

# %% [markdown]
# Cursul de Algebra liniara prezinta metode liniare cu aplicatii in diverse domenii ale *Computer Science* (CS):
#
# * compresia datelor
#
# * cautare pe WEB
#
# * determinarea nodului central intr-o retea
#
# * designul sistemelor de recomandare de servicii si produse
#
# * analiza retelelor sociale
#
# * grafica 2D si 3D
#
# * procesarea imaginii
#
# * *machine learning*, *data mining*, *data science*

# %% [markdown]
# Metodele si tehnicile de baza pe care le studiem le  experimentam prin calcul direct. Pentru aplicatiile in CS,
# care implica folosirea matricilor 2D de dimensiuni mari, folosim pachetul `numpy` si `scipy` din `Python`. In plus pentru vizualizarea datelor vom apela  `matplotlib`, iar pentru generarea si analiza  retelelor, `networkx`.

# %%
from IPython.display import Image
Image(url='https://www.python.org/static/community_logos/python-logo.png')
# Out:
# <img src="https://www.python.org/static/community_logos/python-logo.png"/>

# %% [markdown]
# Descarcati  distributia Python, Anaconda, de la Continuum Analytics:
#     [ContinuumIO](https://store.continuum.io/cshop/anaconda)

# %% [markdown]
# Dupa instalare, sub Windows, identificati  icoana pentru Spyder.

# %%
Image(url='https://code.google.com/p/spyderlib/logo?cct=1379130103')
# Out:
# <img src="https://code.google.com/p/spyderlib/logo?cct=1379130103"/>

# %% [markdown]
#  Spyder este un mediu interactiv de dezvoltare (IDE)
# pentru Python, care permite editarea codului si executarea lui.

# %%
Image(filename='Imag/MeniuSpyder.jpg')

# %% [markdown]
# De ce `Python`?
#
# * Pentru ca este usor de invatat
#
# * Codul in Python este usor citibil
#   si nu necesita managementul memoriei (alocare memorie si testare daca s-a facut alocarea, etc).
# * Python este open source si gratuit.
#
# * Exista o multime de tutoriale pe WEB si o  comunitate activa de dezvoltatori, care acorda asistenta pe [stackoverflow](http://stackoverflow.com/questions/tagged/python), grupuri si liste de discutii.

# %% [markdown]
# In Timisoara exista grupul pasionatilor de `Python`, [`PyTim`](http://www.meetup.com/PyTim-Meetup/).

# %% [markdown]
# > *PyTim is a Python user group which focuses on bringing together all the Python enthusiasts in Timisoara. Whether you are an experienced Python developer or just a beginner, join our community and meet, talk and learn from the best Python hackers in town.*

# %% [markdown]
# `Python` este considerat limbajul oficial la Google:
#
# >*Python has been an important part of Google since the beginning, and remains so as the system grows and evolves. Today dozens of Google engineers use Python, and we're looking for more people with skills in this language." [said Peter Norvig, director of search quality at Google, Inc](http://www.python.org/about/quotes/)*

# %% [markdown]
# Fisierul pe care-l cititi acum  este un [IPython Notebook](http://ipython.org/ipython-doc/stable/interactive/notebook.html), convertit in fisier `html`.

# %%
Image(url='http://ipython.org/ipython-doc/stable/_static/logo.png')
# Out:
# <img src="http://ipython.org/ipython-doc/stable/_static/logo.png"/>

# %% [markdown]
# Ce este IPython Notebook? Raspunsul este dat aici: [IPython Notebook](http://ipython.org/notebook.html)
#
# *The IPython Notebook is a web-based interactive computational environment
# where you can combine code execution, text, mathematics, plots and rich media into a single document*

# %% [markdown]
# Versiunea curenta de IPython Notebook, inclusa in distributia `Anaconda` 1.9, este 2.0.

# %% [markdown]
# Dupa  ce  ati  instalat Anaconda creati un folder numit, de exemplu, Nbooks.
# Apoi din cmd schimbati directorul:
#
# `cd Documents\Nbooks`
#
# In `cmd` invocati IPython Notebook:
#
# `ipython notebook`
#
# Aceasta comanda  starteaza un server WEB si deschide browserul (Chrome, Firefox) la adresa `http://127.0.0.1:8888/`.
# In browser apare dashboard-ul care vizualizeaza toate notebook-urile din director (fisiere cu extensia `ipynb`).

# %% [markdown]
# Daca in prealabil ati descarcat in directorul `Nbooks` acest notebook atunci  dashboard-ul afiseaza numele acestui fisier.
#
# Puteti crea unul nou, dand click pe  butonul `New Notebook` din dashboard.

# %% [markdown]
# Dupa ce un fisier `ipynb` a fost deschis este afisat urmatorul toolbar:

# %%
Image(filename='Imag/toolbar.jpg')

# %% [markdown]
# Un fisier `ipynb` este constituit dintr-o succesiune de celule `Markdown` si  `Code`. In imaginea precedenta celula este setata pe `Code`.

# %% [markdown]
# Inainte de a edita o celula `Markdown` se selecteaza din toolbar `Markdown`.

# %% [markdown]
# Intr-o celula `Markdown` se scrie text uzual sau folosind sintaxa `Markdown`. De exemplu linkurile din acest fisier le-am inserat folosind regula de editare a link-urilor
# din [Markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Here-Cheatsheet)

# %% [markdown]
# Intr-o celula `Markdown` se pot insera si relatii  matematice editate in  LaTeX:
#
# $A\in\mathbb{R}^{m\times n}, \quad  Null(A)=\{v\in\mathbb{R}^n\:|\:  Av=\theta\}$

# %% [markdown]
# Dupa ce s-a editat celula se ruleaza selectand din meniu butonul  $\blacktriangleright$

# %% [markdown]
# Pentru a edita cod Python ce se ruleaza in browser se selecteaza din toolbar `Code`
# si dupa ce s-a editat se da din nou click pe run, adica pe $\blacktriangleright$

# %% [markdown]
# Intr-un notebook  celulele de tip `Code` sunt  cele care incep cu `In[n]`, unde `n` este un numar intreg ce indica
# a cata celula `Code` este celula respectiva. Rezultatul rularii celulei `n` este afisat in celula urmatoare, care incepe cu `Out[n]`.

# %% [markdown]
# Daca s-au facut erori de editare, se selecteaza din toolbar  `Raw NBConvert` (aceeasi locatie unde apare `Code` si `Markdown`). Dupa ce s-au facut corecturile in modul `Raw` se selecteaza
# tipul de celula adecvat si se ruleaza din nou. Prin experimentare veti realiza care este procedura.

# %% [markdown]
# Sa dam acum un exemplu de cod Python (mai multe detalii in urmatorul notebook ce se va posta). Acest notebook are scopul doar de a evidentia capabilitatile
# acestui instrument de predare/invatare.

# %%
# O linie care incepe cu diez # este o linie de comentariu
import numpy as np # importam modulul `numpy` ce contine functii ce opereaza asupra array-urilor

A=np.array([[2,-1],[3,4]], float)
print A # acum dam run si:
# Out:
# [[ 2. -1.]
#  [ 3.  4.]]

# %%
#calculam determinantul lui A
d=np.linalg.det(A)
print 'determinatul este: ', d
# Out:
# determinatul este:  11.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
x=np.arange(0, 2*np.pi, 0.01)
y=np.sin(2*x)+0.5*np.cos(x)
plt.plot(x,y,'r')# deseneaza graficul functiei  y(x)=sin(2x)+0.5 cos(x)

# %% [markdown]
# Intr-o celula se poate rula si un script extern, de pe WEB, folosind comanda magica `%load`. Scriptul este incarcat in  celula imediat urmatoare si poate fi editat inainte de rulare.

# %%
# %load  http://matplotlib.org/mpl_examples/images_contours_and_fields/pcolormesh_levels.py

# %%
"""
Shows how to combine Normalization and Colormap instances to draw
"levels" in pcolor, pcolormesh and imshow type plots in a similar
way to the levels keyword argument to contour/contourf.

"""

import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
import numpy as np


# make these smaller to increase the resolution
dx, dy = 0.05, 0.05

# generate 2 2d grids for the x & y bounds
y, x = np.mgrid[slice(1, 5 + dy, dy),
                slice(1, 5 + dx, dx)]

z = np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# x and y are bounds, so z should be the value *inside* those bounds.
# Therefore, remove the last value from the z array.
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())


# pick the desired colormap, sensible levels, and define a normalization
# instance which takes data values and translates those into levels.
cmap = plt.get_cmap('PiYG')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)

plt.subplot(2, 1, 1)
im = plt.pcolormesh(x, y, z, cmap=cmap, norm=norm)
plt.colorbar()
# set the limits of the plot to the limits of the data
plt.axis([x.min(), x.max(), y.min(), y.max()])
plt.title('pcolormesh with levels')



plt.subplot(2, 1, 2)
# contours are *point* based plots, so convert our bound into point
# centers
plt.contourf(x[:-1, :-1] + dx / 2.,
             y[:-1, :-1] + dy / 2., z, levels=levels,
             cmap=cmap)
plt.colorbar()
plt.title('contourf with levels')


plt.show()

# %%
"""
Shows how to combine Normalization and Colormap instances to draw
"levels" in pcolor, pcolormesh and imshow type plots in a similar
way to the levels keyword argument to contour/contourf.

"""

import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
import numpy as np


# make these smaller to increase the resolution
dx, dy = 0.05, 0.05

# generate 2 2d grids for the x & y bounds
y, x = np.mgrid[slice(1, 5 + dy, dy),
                slice(1, 5 + dx, dx)]

z = np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# x and y are bounds, so z should be the value *inside* those bounds.
# Therefore, remove the last value from the z array.
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())


# pick the desired colormap, sensible levels, and define a normalization
# instance which takes data values and translates those into levels.
cmap = plt.get_cmap('PiYG')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)

plt.subplot(2, 1, 1)
im = plt.pcolormesh(x, y, z, cmap=cmap, norm=norm)
plt.colorbar()
# set the limits of the plot to the limits of the data
plt.axis([x.min(), x.max(), y.min(), y.max()])
plt.title('pcolormesh with levels')



plt.subplot(2, 1, 2)
# contours are *point* based plots, so convert our bound into point
# centers
plt.contourf(x[:-1, :-1] + dx / 2.,
             y[:-1, :-1] + dy / 2., z, levels=levels,
             cmap=cmap)
plt.colorbar()
plt.title('contourf with levels')


plt.show()

# %%
"""
Shows how to combine Normalization and Colormap instances to draw
"levels" in pcolor, pcolormesh and imshow type plots in a similar
way to the levels keyword argument to contour/contourf.

"""

import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
import numpy as np


# make these smaller to increase the resolution
dx, dy = 0.05, 0.05

# generate 2 2d grids for the x & y bounds
y, x = np.mgrid[slice(1, 5 + dy, dy),
                slice(1, 5 + dx, dx)]

z = np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# x and y are bounds, so z should be the value *inside* those bounds.
# Therefore, remove the last value from the z array.
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())


# pick the desired colormap, sensible levels, and define a normalization
# instance which takes data values and translates those into levels.
cmap = plt.get_cmap('PiYG')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)

# contours are *point* based plots, so convert our bound into point
# centers
plt.contourf(x[:-1, :-1] + dx / 2.,
             y[:-1, :-1] + dy / 2., z, levels=levels,
             cmap=cmap)
plt.colorbar()
plt.title('contourf with levels')


plt.show()

# %% [markdown]
# Parintele sistemului IPython (un shell interactiv pentru Python) este
# [Fernando Perez](http://www.fsf.org/news/2012-free-software-award-winners-announced-2).
#
# In video-ul urmator Fernando prezinta evolutia proiectului `IPython` in cei 12 ani de la startare.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('F4rFuIb1Ie4')
# Out:
#         <iframe
#             width="400"
#             height=300"
#             src="https://www.youtube.com/embed/F4rFuIb1Ie4"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Pentru a afisa un video de pe youtube sau vimeo este necesar doar `id`-ul videoului.

# %%
from IPython.display import VimeoVideo
VimeoVideo(78015169)
# Out:
#         <iframe
#             width="400"
#             height=300"
#             src="https://player.vimeo.com/video/78015169"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Intr-un frame se poate afisa linkul la un slideshow de pe `slideshare.net`. `embed_code` se identifica din sursa `html` a paginii respective:

# %%
from IPython.display import IFrame
IFrame("http://www.slideshare.net/slideshow/embed_code/27653235", 400, 300)
# Out:
#         <iframe
#             width="400"
#             height=300"
#             src="http://www.slideshare.net/slideshow/embed_code/27653235"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Ipython Notebook poate vizualiza si imagini de pe WEB,  de exemplu de pe Facebook:

# %%
Image(url='https://fbcdn-profile-a.akamaihd.net/hprofile-ak-ash3/70946_100002783183106_1626676861_q.jpg')
# Out:
# <img src="https://fbcdn-profile-a.akamaihd.net/hprofile-ak-ash3/70946_100002783183106_1626676861_q.jpg"/>

# %% [markdown]
# Din notebook se pot urmari cursuri  online:
# [Least  Square Examples - KhanAcademy](https://www.khanacademy.org/math/linear-algebra/alternate_bases/orthogonal_projections/v/linear-algebra--least-squares-examples)

# %%
YouTubeVideo('8mAZYv5wIcE')
# Out:
#         <iframe
#             width="400"
#             height=300"
#             src="https://www.youtube.com/embed/8mAZYv5wIcE"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# In concluzie, Ipython si Ipython Notebook ofera instrumente open source pentru calcul interactiv in Python.
#
#
# IPython Notebook  afiseaza  orice tip de date ce pot fi afisate in browser:
# imagini, video-uri,  fisiere locale, etc
#
# Noi vom folosi IPython Notebook pentru a crea  cursuri si seminarii executabile. In celule cod vom introduce cod ce ilustreaza diverse metode liniare folosite in CS:
#
#  - dreapta celor mai mici patrate
#
#  - algoritmi ce extrag informatia codificata de matricea de conectivitate a unei retele (care este nodul central intr-o retea, care este indicele lui de popularitate, etc)
#
#  - compresia unei imagini prin  aplicarea descompunerii  SVD a  matricii de pixeli, ce defineste imaginea
#
#  - transformari liniare in grafica 2D si 3D
#
#  -  generarea interactiva a curbelor plane si in spatiu, date analitic, a curbelor Bezier
#
#  -  etc

# %% [markdown]
# - Pentru prima experimentare, puteti modifica fisierul `ipynb` al acestui notebook. Rularea celulelor se face succesiv. Daca incercati sa rulati
# o celula interioara s-ar putea sa genereze erori, pentru ca nu au fost rulate celulele precedente care importau
# diverse module sau functii din module!!!!!

# %% [markdown]
# - Un IPython Notebook se poate converti intr-un fisier `html`, static, dand comanda:
#
#   `ipython nbconvert NumeNbook.ipynb --to hml`

# %% [markdown]
# - Conversia este posibila daca in prealabil a fost instalat [pandoc](http://johnmacfarlane.net/pandoc/installing.html).

# %% [markdown]
# Fisierul  `NumeNbook.html`, generat, se insereaza apoi intr-o  pagina WEB.
#
# - O a doua posibilitate este sa se insereze intr-o pagina, `http://www.adresa.ro/FolderNbooks`,
#     doar fisierul `ipynb` si apoi sa fie invocat serviciul WEB, gratuit, `nbviewer`,  [notebook viewer](http://nbviewer.ipython.org/), inserand in pagina linkul:
#
# `http://nbviewer.ipython.org/url/adresa.ro/FolderNbooks/NumeNbook.ipynb`
#
# - Fisierele `ipynb` stocate in contul de `github` al autorului pot fi vizualizate ca fisiere `html`,  apeland de asemenea serviciul `nbviewer`.

# %% [markdown]
# E Petrisor, Universitatea Politehnica Timisoara

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("./styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
#     .prompt{
#         display: None;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 22pt;
#         color: #4057A1;
#         font-style: italic;
# ...
